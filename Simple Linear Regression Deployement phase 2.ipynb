# %%
import pickle

# %%
loaded_model=pickle.load(open('finalized_model_linear.sav','rb'))
result1=loaded_model.predict([[13]])
result2=loaded_model.predict([[0]])
# Out:
# C:\Users\khavy\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\khavy\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print(result1,result2)     #for result2 - 0yrs of experience - shows intercept value(bias)

#y=wx+b, 0x+b  for 0 experience
# Out:
# [[147326.50074449]] [[25918.43833489]]
